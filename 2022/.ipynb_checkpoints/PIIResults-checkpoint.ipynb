# %% [markdown]
# ## PDF Results Parsing
#
# # Takes Utah Division of Wildlife Personal Info PDF and converts it to CSV

# %% [markdown]
# Default open page

# %%
# open/load pdf file
import pdfplumber

pdf = pdfplumber.open('2022_results.pdf')

p0 = pdf.pages[0]

im = p0.to_image()
im

# %%
# check default table settings
im.reset().debug_tablefinder()

# %% [markdown]
# Since we have horiziontal lines w/ pdf and we're missing vertical lines, we explicitly pick vertical lines that work for the pages. Use debug tablefinder to visualize and see what we're doing

# %%
# table debug
table_settings = {
    "horizontal_strategy": "lines",
    "explicit_vertical_lines": [35, 200, 360, 485, 590, 750]
}

im.reset().debug_tablefinder(table_settings)

# %% [markdown]
# ## Test Extraction of the first page using table settings

# %%
p0.extract_table(table_settings)
# Out:
# [['TRISTAN P ADAMS',
#   '5 - Unsuccessful',
#   '3478 S Cozy River Pl Apt \n409',
#   'West Valley City UT \n84119-4507',
#   'BI6500 - Antelope Island Bison'],
#  ['CRAIG D ADAMSON',
#   '5 - Unsuccessful',
#   '2865 W 1425 N',
#   'Layton UT \n84041-3453',
#   'BI6500 - Antelope Island Bison'],
#  ['Greg D Allsop',
#   '5 - Unsuccessful',
#   '902 W 2075 S',
#   'Syracuse UT \n84075-9163',
#   'BI6500 - Antelope Island Bison'],
#  ['Justin G Alvey',
#   '5 - Unsuccessful',
#   'PO Box 570096',
#   'Sigurd UT 84657-0096',
#   'BI6500 - Antelope Island Bison'],
#  ['PAMELA S ANDERSON',
#   '5 - Unsuccessful',
#   '6445 S 1600 W',
#   'Hyrum UT 84319-7101',
#   'BI6500 - Antelope Island Bison'],
#  ['JEFF C ANDREWS',
#   '5 - Unsuccessful',
#   '53 S 1st St',
#   'Tooele UT 84074-2114',
#   'BI6500 - Antelope Island Bison'],
#  ['RONALD S ARRINGTON',
#   '5 - Unsuccessful',
#   '322 W 1250 N',
#   'Centerville UT \n84014-1102',
#   'BI6500 - Antelope Island Bison'],
#  ['JAY S ATKINS',
#   '5 - Unsuccessful',
#   '8567 S Maul Oak Dr',
#   'West Jordan UT \n84081-1847',
#   'BI6500 - Antelope Island Bison'],
#  ['JOSHUA D AZERA',
#   '5 - Unsuccessful',
#   '8399 S 3200 W',
#   'West Jordan UT \n84088-5222',
#   'BI6500 - Antelope Island Bison'],
#  ['BRANDON L BAKER',
#   '5 - Unsuccessful',
#   '4046 W Adler Rd',
#   'Riverton UT \n84096-1245',
#   'BI6500 - Antelope Island Bison'],
#  ['Jordan Y Baker',
#   '5 - Unsuccessful',
#   '6488 W Bridge Maple Ln',
#   'West Jordan UT \n84081-4168',
#   'BI6500 - Antelope Island Bison'],
#  ['Jarom B Bangerter',
#   '5 - Unsuccessful',
#   '665 E 200 S',
#   'Heber City UT \n84032-2142',
#   'BI6500 - Antelope Island Bison'],
#  ['Byron W Barker',
#   '5 - Unsuccessful',
#   '5385 W 8800 N',
#   'Tremonton UT \n84337-8648',
#   'BI6500 - Antelope Island Bison'],
#  ['GAVIN M BARLOW',
#   '5 - Unsuccessful',
#   '4661 N 25 E',
#   'Enoch UT 84721-7485',
#   'BI6500 - Antelope Island Bison'],
#  ['Jason M Barlow',
#   '5 - Unsuccessful',
#   '4661 N 25 E',
#   'Enoch UT 84721-7485',
#   'BI6500 - Antelope Island Bison'],
#  ['Ryan N Barney',
#   '5 - Unsuccessful',
#   '11091 S Windy Peak \nRidge Dr',
#   'Sandy UT 84094-5445',
#   'BI6500 - Antelope Island Bison'],
#  ['KYLEE R BARRETT',
#   '5 - Unsuccessful',
#   '465 N 3550 W',
#   'Layton UT \n84041-3712',
#   'BI6500 - Antelope Island Bison'],
#  ['Jacob J Bawden',
#   '5 - Unsuccessful',
#   '13208 S 2420 W',
#   'Riverton UT \n84065-2234',
#   'BI6500 - Antelope Island Bison'],
#  ['Brock M Bean',
#   '5 - Unsuccessful',
#   '11492 N Maple Hollow Ct',
#   'Highland UT \n84003-5635',
#   'BI6500 - Antelope Island Bison'],
#  ['Alex B Bench',
#   '5 - Unsuccessful',
#   '1754 N 1770 E',
#   'Mapleton UT \n84664-4128',
#   'BI6500 - Antelope Island Bison']]

# %% [markdown]
# ## Create table using pdf data
#
# Table is used later to write to csv, see output to determine structure

# %%
with pdfplumber.open('2022_results.pdf') as pdf:
    for page in pdf.pages:
        try:
            table += page.extract_table(table_settings)
        except:
            pass
table
# Out:
# [['TRISTAN P ADAMS',
#   '5 - Unsuccessful',
#   '3478 S Cozy River Pl Apt 409',
#   'West Valley City UT 84119-4507',
#   'BI6500 - Antelope Island Bison'],
#  ['CRAIG D ADAMSON',
#   '5 - Unsuccessful',
#   '2865 W 1425 N',
#   'Layton UT 84041-3453',
#   'BI6500 - Antelope Island Bison'],
#  ['Greg D Allsop',
#   '5 - Unsuccessful',
#   '902 W 2075 S',
#   'Syracuse UT 84075-9163',
#   'BI6500 - Antelope Island Bison'],
#  ['Justin G Alvey',
#   '5 - Unsuccessful',
#   'PO Box 570096',
#   'Sigurd UT 84657-0096',
#   'BI6500 - Antelope Island Bison'],
#  ['PAMELA S ANDERSON',
#   '5 - Unsuccessful',
#   '6445 S 1600 W',
#   'Hyrum UT 84319-7101',
#   'BI6500 - Antelope Island Bison'],
#  ['JEFF C ANDREWS',
#   '5 - Unsuccessful',
#   '53 S 1st St',
#   'Tooele UT 84074-2114',
#   'BI6500 - Antelope Island Bison'],
#  ['RONALD S ARRINGTON',
#   '5 - Unsuccessful',
#   '322 W 1250 N',
#   'Centerville UT 84014-1102',
#   'BI6500 - Antelope Island Bison'],
#  ['JAY S ATKINS',
#   '5 - Unsuccessful',
#   '8567 S Maul Oak Dr',
#   'West Jordan UT 84081-1847',
#   'BI6500 - Antelope Island Bison'],
#  ['JOSHUA D AZERA',
#   '5 - Unsuccessful',
#   '8399 S 3200 W',
#   'West Jordan UT 84088-5222',
#   'BI6500 - Antelope Island Bison'],
#  ['BRANDON L BAKER',
#   '5 - Unsuccessful',
#   '4046 W Adler Rd',
#   'Riverton UT 84096-1245',
#   'BI6500 - Antelope Island Bison'],
#  ['Jordan Y Baker',
#   '5 - Unsuccessful',
#   '6488 W Bridge Maple Ln',
#   'West Jordan UT 84081-4168',
#   'BI6500 - Antelope Island Bison'],
#  ['Jarom B Bangerter',
#   '5 - Unsuccessful',
#   '665 E 200 S',
#   'Heber City UT 84032-2142',
#   'BI6500 - Antelope Island Bison'],
#  ['Byron W Barker',
#   '5 - Unsuccessful',
#   '5385 W 8800 N',
#   'Tremonton UT 84337-8648',
#   'BI6500 - Antelope Island Bison'],
#  ['GAVIN M BARLOW',
#   '5 - Unsuccessful',
#   '4661 N 25 E',
#   'Enoch UT 84721-7485',
#   'BI6500 - Antelope Island Bison'],
#  ['Jason M Barlow',
#   '5 - Unsuccessful',
#   '4661 N 25 E',
#   'Enoch UT 84721-7485',
#   'BI6500 - Antelope Island Bison'],
#  ['Ryan N Barney',
#   '5 - Unsuccessful',
#   '11091 S Windy Peak Ridge Dr',
#   'Sandy UT 84094-5445',
#   'BI6500 - Antelope Island Bison'],
#  ['KYLEE R BARRETT',
#   '5 - Unsuccessful',
#   '465 N 3550 W',
#   'Layton UT 84041-3712',
#   'BI6500 - Antelope Island Bison'],
#  ['Jacob J Bawden',
#   '5 - Unsuccessful',
#   '13208 S 2420 W',
#   'Riverton UT 84065-2234',
#   'BI6500 - Antelope Island Bison'],
#  ['Brock M Bean',
#   '5 - Unsuccessful',
#   '11492 N Maple Hollow Ct',
#   'Highland UT 84003-5635',
#   'BI6500 - Antelope Island Bison'],
#  ['Alex B Bench',
#   '5 - Unsuccessful',
#   '1754 N 1770 E',
#   'Mapleton UT 84664-4128',
#   'BI6500 - Antelope Island Bison'],
#  ['karen berthold',
#   '5 - Unsuccessful',
#   '1230 Northridge Dr',
#   'Bountiful UT 84010-1710',
#   'BI6500 - Antelope Island Bison'],
#  ['STEPHEN E BIALKOWSKI',
#   '5 - Unsuccessful',
#   '121 N 300 E',
#   'Hyde Park UT 84318-3419',
#   'BI6500 - Antelope Island Bison'],
#  ['Jack S Bishop',
#   '5 - Unsuccessful',
#   '468 E Ridgeview Cir',
#   'Ivins UT 84738-6738',
#   'BI6500 - Antelope Island Bison'],
#  ['MASON E BLACKHAM',
#   '5 - Unsuccessful',
#   '253 N 780 E',
#   'Salem UT 84653-5532',
#   'BI6500 - Antelope Island Bison'],
#  ['MORGAN N BLACKHAM',
#   '5 - Unsuccessful',
#   '253 N 780 E',
#   'Salem UT 84653-5532',
#   'BI6500 - Antelope Island Bison'],
#  ['Steven P Blackhurst',
#   '5 - Unsuccessful',
#   '10173 N Mystic Holw',
#   'Highland UT 84003-2610',
#   'BI6500 - Antelope Island Bison'],
#  ['Layne H Blake',
#   '5 - Unsuccessful',
#   '2676 W 3900 S',
#   'Roy UT 84067-9694',
#   'BI6500 - Antelope Island Bison'],
#  ['BROOKE BOHRER',
#   '5 - Unsuccessful',
#   '2429 W 2075 N',
#   'Clinton UT 84015-7661',
#   'BI6500 - Antelope Island Bison'],
#  ['GERALD G BOYER',
#   '5 - Unsuccessful',
#   '5925 S 1075 E',
#   'Ogden UT 84405-4915',
#   'BI6500 - Antelope Island Bison'],
#  ['Larry D Bringhurst',
#   '5 - Unsuccessful',
#   '405 E 1200 N',
#   'Mapleton UT 84664-3704',
#   'BI6500 - Antelope Island Bison'],
#  ['TAYLAR BRITTAIN',
#   '5 - Unsuccessful',
#   '1457 S 2950 E',
#   'Spanish Fork UT 84660-3110',
#   'BI6500 - Antelope Island Bison'],
#  ['Donald L Brown',
#   '5 - Unsuccessful',
#   'PO Box 219',
#   'Hinckley UT 84635-0219',
#   'BI6500 - Antelope Island Bison'],
#  ['MATTHEW R BROWN',
#   '5 - Unsuccessful',
#   '12827 S Tortoise Ln',
#   'Riverton UT 84096-5500',
#   'BI6500 - Antelope Island Bison'],
#  ['SAGE M BROWN',
#   '5 - Unsuccessful',
#   '510 N 100 W',
#   'Kanab UT 84741-3255',
#   'BI6500 - Antelope Island Bison'],
#  ['James R Bruce',
#   '5 - Unsuccessful',
#   '926 E Statice Ave',
#   'Sandy UT 84094-4506',
#   'BI6500 - Antelope Island Bison'],
#  ['ZACHARY P BRYANT',
#   '5 - Unsuccessful',
#   '426 N Locust Ave',
#   'Lindon UT 84042-1313',
#   'BI6500 - Antelope Island Bison'],
#  ['MARY E BURBANK',
#   '5 - Unsuccessful',
#   '6248 W Center St',
#   'Mendon UT 84325-9747',
#   'BI6500 - Antelope Island Bison'],
#  ['Danielle M Burgener',
#   '5 - Unsuccessful',
#   '3743 W Salinas Dr',
#   'Riverton UT 84065-7637',
#   'BI6500 - Antelope Island Bison'],
#  ['DALLIN BUTLER',
#   '5 - Unsuccessful',
#   '3089 E Sandpiper Rd',
#   'Eagle Mountain UT 84005-6117',
#   'BI6500 - Antelope Island Bison'],
#  ['BAILEY J CALDER',
#   '5 - Unsuccessful',
#   '1504 E Pheasant Run Dr',
#   'Springville UT 84663-3826',
#   'BI6500 - Antelope Island Bison'],
#  ['BRIDGET CALDER',
#   '5 - Unsuccessful',
#   '1504 E Pheasant Run Dr',
#   'Springville UT 84663-3826',
#   'BI6500 - Antelope Island Bison'],
#  ['TASIA L CARSON',
#   '5 - Unsuccessful',
#   '1562 W 590 N',
#   'Lindon UT 84042-2079',
#   'BI6500 - Antelope Island Bison'],
#  ['WYATT R CARVER',
#   '5 - Unsuccessful',
#   '5641 N Fork Rd',
#   'Eden UT 84310-9685',
#   'BI6500 - Antelope Island Bison'],
#  ['RUSSELL B CASE',
#   '5 - Unsuccessful',
#   '2504 W Main Canyon Rd',
#   'Wallsburg UT 84082-9740',
#   'BI6500 - Antelope Island Bison'],
#  ['RYLAN CEDARSTROM',
#   '5 - Unsuccessful',
#   '174 W 300 S',
#   'Midway UT 84049-6512',
#   'BI6500 - Antelope Island Bison'],
#  ['CHARLES V CHADWICK JR',
#   '5 - Unsuccessful',
#   '1232 S 775 E',
#   'Ogden UT 84404-5826',
#   'BI6500 - Antelope Island Bison'],
#  ['RICARDO L CHASTAIN',
#   '5 - Unsuccessful',
#   '1194 E Black Brush Dr',
#   'Washington UT 84780-2568',
#   'BI6500 - Antelope Island Bison'],
#  ['ZACHARY E CHATWIN',
#   '5 - Unsuccessful',
#   '418 W 500 S',
#   'Payson UT 84651-2708',
#   'BI6500 - Antelope Island Bison'],
#  ['Andrew D Christensen',
#   '5 - Unsuccessful',
#   '2718 S 450 E',
#   'Bountiful UT 84010-4317',
#   'BI6500 - Antelope Island Bison'],
#  ['ROGER L CHRISTENSEN',
#   '5 - Unsuccessful',
#   '691 3 O Clock Dr',
#   'Tooele UT 84074-2593',
#   'BI6500 - Antelope Island Bison'],
#  ['Scott B Christensen',
#   '5 - Unsuccessful',
#   '967 W Fremont Ave',
#   'Salt Lake City UT 84104-2006',
#   'BI6500 - Antelope Island Bison'],
#  ['Taylor B Christensen',
#   '5 - Unsuccessful',
#   '2775 E Westerling Way',
#   'Cottonwood Heights UT 84121-5239',
#   'BI6500 - Antelope Island Bison'],
#  ['JASON F CLEGG',
#   '5 - Unsuccessful',
#   '884 E Kaseys Cir',
#   'Draper UT 84020-7611',
#   'BI6500 - Antelope Island Bison'],
#  ['CEDAR C COBURN',
#   '5 - Unsuccessful',
#   '708 S State St',
#   'Genola UT 84655-6089',
#   'BI6500 - Antelope Island Bison'],
#  ['NICHOLAS P COCHRAN',
#   '5 - Unsuccessful',
#   '6544 W Haven Maple Dr',
#   'West Jordan UT 84081-4162',
#   'BI6500 - Antelope Island Bison'],
#  ['MARK S COLLARD',
#   '5 - Unsuccessful',
#   '4858 W 5500 S',
#   'Hooper UT 84315-9515',
#   'BI6500 - Antelope Island Bison'],
#  ['SHANNON M COLTON',
#   '5 - Unsuccessful',
#   '982 W Porter Ln',
#   'West Bountiful UT 84087-2403',
#   'BI6500 - Antelope Island Bison'],
#  ['RYAN D CONRAD',
#   '5 - Unsuccessful',
#   '973 W 1500 S',
#   'Springville UT 84663-5920',
#   'BI6500 - Antelope Island Bison'],
#  ['KASH M COOK',
#   '5 - Unsuccessful',
#   'PO Box 518',
#   'Moroni UT 84646-0518',
#   'BI6500 - Antelope Island Bison'],
#  ['PHILLIP J COOK',
#   '5 - Unsuccessful',
#   'PO Box 518',
#   'Moroni UT 84646-0518',
#   'BI6500 - Antelope Island Bison'],
#  ['ALEX P COOMBS',
#   '5 - Unsuccessful',
#   '1283 W Johnson Ridge Ln',
#   'West Jordan UT 84084-3580',
#   'BI6500 - Antelope Island Bison'],
#  ['BRETT M COOMBS',
#   '5 - Unsuccessful',
#   '362 W 2030 N',
#   'Tooele UT 84074-3743',
#   'BI6500 - Antelope Island Bison'],
#  ['Robert A Cox',
#   '5 - Unsuccessful',
#   '1438 N 1350 W',
#   'Farr West UT 84404-3483',
#   'BI6500 - Antelope Island Bison'],
#  ['AYDEN C DABB',
#   '5 - Unsuccessful',
#   '5060 Vista Dr',
#   'Roy UT 84067-7707',
#   'BI6500 - Antelope Island Bison'],
#  ['MATTHEW DAVIS',
#   '5 - Unsuccessful',
#   '6141 W Cherry Springs Ct',
#   'Salt Lake City UT 84118-9303',
#   'BI6500 - Antelope Island Bison'],
#  ['KYLE F DAY',
#   '5 - Unsuccessful',
#   '512 Church St',
#   'Layton UT 84041-3112',
#   'BI6500 - Antelope Island Bison'],
#  ['WYATT C DESPAIN',
#   '5 - Unsuccessful',
#   '5054 W ARIENE LANE',
#   'SALT LAKE CITY UT 84120',
#   'BI6500 - Antelope Island Bison'],
#  ['CURTIS M DEYOUNG',
#   '5 - Unsuccessful',
#   '3751 W Ridges Rd',
#   'Morgan UT 84050-8707',
#   'BI6500 - Antelope Island Bison'],
#  ['TONIA J DOWNWARD',
#   '5 - Unsuccessful',
#   '652 S Hale St',
#   'Grantsville UT 84029-9673',
#   'BI6500 - Antelope Island Bison'],
#  ['Daniel W Draper',
#   '5 - Unsuccessful',
#   '5707 W 10620 N',
#   'Highland UT 84003-9125',
#   'BI6500 - Antelope Island Bison'],
#  ['Brandon M Dutson',
#   '5 - Unsuccessful',
#   '1454 Wallace Dr',
#   'Springville UT 84663-3509',
#   'BI6500 - Antelope Island Bison'],
#  ['Tony R Earley',
#   '5 - Unsuccessful',
#   'PO Box 212',
#   'Laketown UT 84038-0212',
#   'BI6500 - Antelope Island Bison'],
#  ['MARKEE EGGETT',
#   '5 - Unsuccessful',
#   '838 W 3300 N',
#   'Pleasant Grove UT 84062-8758',
#   'BI6500 - Antelope Island Bison'],
#  ['Deena K Ericksen',
#   '5 - Unsuccessful',
#   '8340 W 3680 S',
#   'Magna UT 84044-2292',
#   'BI6500 - Antelope Island Bison'],
#  ['DALLAS j ESKELSON',
#   '5 - Unsuccessful',
#   '5824 W Moon Shadow Dr',
#   'Herriman UT 84096-1775',
#   'BI6500 - Antelope Island Bison'],
#  ['Charles S Evans',
#   '5 - Unsuccessful',
#   '915 N 600 W',
#   'West Bountiful UT 84087-1338',
#   'BI6500 - Antelope Island Bison'],
#  ['JACK A EVANS',
#   '5 - Unsuccessful',
#   '14847S S Redwood Rd',
#   'Bluffdale UT 84065-3736',
#   'BI6500 - Antelope Island Bison'],
#  ['MORGAN L EWELL',
#   '5 - Unsuccessful',
#   '5743 W 12815 S',
#   'Herriman UT 84096-8965',
#   'BI6500 - Antelope Island Bison'],
#  ['TAMERA J FARR',
#   '5 - Unsuccessful',
#   '256 W 2600 N',
#   'Lehi UT 84043-3360',
#   'BI6500 - Antelope Island Bison'],
#  ['BRIAN FIRTH',
#   '5 - Unsuccessful',
#   '1321 S 840 W',
#   'Woods Cross UT 84087-2000',
#   'BI6500 - Antelope Island Bison'],
#  ['HENNING P FISCHER',
#   '5 - Unsuccessful',
#   '473 Emery Ave',
#   'Orem UT 84057-3725',
#   'BI6500 - Antelope Island Bison'],
#  ['ALEXIS FISHER',
#   '5 - Unsuccessful',
#   '6817 S 375 E',
#   'South Weber UT 84405-7244',
#   'BI6500 - Antelope Island Bison'],
#  ['AUBREY D FOGARTY',
#   '5 - Unsuccessful',
#   '1214 E Harvard Ave',
#   'Salt Lake City UT 84105-1906',
#   'BI6500 - Antelope Island Bison'],
#  ['Michael N France',
#   '5 - Unsuccessful',
#   '288 S House Rock Cir',
#   'Cedar City UT 84720-6723',
#   'BI6500 - Antelope Island Bison'],
#  ['Darren R Franz',
#   '5 - Unsuccessful',
#   '2610 W Pine Meadow Pl',
#   'Salt Lake City UT 84129-1556',
#   'BI6500 - Antelope Island Bison'],
#  ['KIM E FULLER',
#   '5 - Unsuccessful',
#   '1711 W River View Dr',
#   'Bluffdale UT 84065-3772',
#   'BI6500 - Antelope Island Bison'],
#  ['JACOB M GALLEGOS',
#   '5 - Unsuccessful',
#   '4670 S 6300 W',
#   'Hooper UT 84315-9742',
#   'BI6500 - Antelope Island Bison'],
#  ['JOSHUA L GALLEGOS',
#   '5 - Unsuccessful',
#   '4670 S 6300 W',
#   'Hooper UT 84315-9742',
#   'BI6500 - Antelope Island Bison'],
#  ['Megan R Gallegos',
#   '5 - Unsuccessful',
#   '4670 S 6300 W',
#   'Hooper UT 84315-9742',
#   'BI6500 - Antelope Island Bison'],
#  ['Nathan M Gallegos',
#   '5 - Unsuccessful',
#   '3662 Rose Springs Rd',
#   'Tooele UT 84074-5517',
#   'BI6500 - Antelope Island Bison'],
#  ['Richard M Gallegos',
#   '5 - Unsuccessful',
#   '4670 S 6300 W',
#   'Hooper UT 84315-9742',
#   'BI6500 - Antelope Island Bison'],
#  ['GEORGE D GAREE',
#   '5 - Unsuccessful',
#   '9962 S Eden Ridge Dr',
#   'South Jordan UT 84095-3016',
#   'BI6500 - Antelope Island Bison'],
#  ['LEONARD B GAREE',
#   '5 - Unsuccessful',
#   '9962 S Eden Ridge Dr',
#   'South Jordan UT 84095-3016',
#   'BI6500 - Antelope Island Bison'],
#  ['CLUFF M GIBSON',
#   '5 - Unsuccessful',
#   '14084 S Lewiston Peak Dr',
#   'Herriman UT 84096-6411',
#   'BI6500 - Antelope Island Bison'],
#  ['VAL D GIBSON',
#   '5 - Unsuccessful',
#   '251 W 255 S',
#   'Orem UT 84058-5469',
#   'BI6500 - Antelope Island Bison'],
#  ['SAWYER R GILES',
#   '5 - Unsuccessful',
#   '1004 E Scenic Dr',
#   'Spanish Fork UT 84660-2921',
#   'BI6500 - Antelope Island Bison'],
#  ['GREG R GRIFFITH',
#   '5 - Unsuccessful',
#   '8328 W Alpha Dr',
#   'Magna UT 84044-3013',
#   'BI6500 - Antelope Island Bison'],
#  ['Sidney T Grimes',
#   '5 - Unsuccessful',
#   '3794 W 4525 S',
#   'West Haven UT 84401-8481',
#   'BI6500 - Antelope Island Bison'],
#  ['MARK S GUNNELL',
#   '5 - Unsuccessful',
#   '175 E 200 N',
#   'Providence UT 84332-9607',
#   'BI6500 - Antelope Island Bison'],
#  ['ARCADIA HABEL',
#   '5 - Unsuccessful',
#   '493 E Calinas Creek Cir',
#   'Murray UT 84107-6600',
#   'BI6500 - Antelope Island Bison'],
#  ['RICHARD HABEL',
#   '5 - Unsuccessful',
#   '493 E Calinas Creek Cir',
#   'Murray UT 84107-6600',
#   'BI6500 - Antelope Island Bison'],
#  ['Steven R Habel',
#   '5 - Unsuccessful',
#   '5098 S Honey Clover Ct',
#   'Murray UT 84123-8422',
#   'BI6500 - Antelope Island Bison'],
#  ['Barry K Hallsted',
#   '5 - Unsuccessful',
#   '10262 N Honeycut Cir',
#   'Cedar Hills UT 84062-8654',
#   'BI6500 - Antelope Island Bison'],
#  ['ALEX T HALSTEAD',
#   '5 - Unsuccessful',
#   '4754 E Silver Mountain Road N',
#   'Eagle Mountain UT 84005',
#   'BI6500 - Antelope Island Bison'],
#  ['THOMAS A HALSTEAD',
#   '5 - Unsuccessful',
#   '25 E Ann Arbor Dr',
#   'Draper UT 84020-3417',
#   'BI6500 - Antelope Island Bison'],
#  ['Thomas M Halstead',
#   '5 - Unsuccessful',
#   '25 E Ann Arbor Dr',
#   'Draper UT 84020-3417',
#   'BI6500 - Antelope Island Bison'],
#  ['DAVID J HALVERSON',
#   '5 - Unsuccessful',
#   '1860 Malan Ct',
#   'Ogden UT 84403-0564',
#   'BI6500 - Antelope Island Bison'],
#  ['KENNETH HAMMON',
#   '5 - Unsuccessful',
#   'PO Box 94',
#   'Richmond UT 84333-0094',
#   'BI6500 - Antelope Island Bison'],
#  ['Braiden M Hampton',
#   '5 - Unsuccessful',
#   '1375 N 1750 W',
#   'Provo UT 84604-2285',
#   'BI6500 - Antelope Island Bison'],
#  ['Aaron D Hansen',
#   '5 - Unsuccessful',
#   '265 W Kays Dr',
#   'Kaysville UT 84037-6791',
#   'BI6500 - Antelope Island Bison'],
#  ['david R Hansen',
#   '5 - Unsuccessful',
#   '855 S 200 E',
#   'Santaquin UT 84655-5582',
#   'BI6500 - Antelope Island Bison'],
#  ['DEVON C HANSEN',
#   '5 - Unsuccessful',
#   '106 Country Clb',
#   'Stansbury Park UT 84074-9143',
#   'BI6500 - Antelope Island Bison'],
#  ['KIM D HANSEN',
#   '5 - Unsuccessful',
#   '515 E 400 N',
#   'Salem UT 84653-9235',
#   'BI6500 - Antelope Island Bison'],
#  ['Kirk E Hansen',
#   '5 - Unsuccessful',
#   '4342 S 4580 W',
#   'West Valley UT 84120-5038',
#   'BI6500 - Antelope Island Bison'],
#  ['Marshall P Hansen',
#   '5 - Unsuccessful',
#   '345 W Center St',
#   'Aurora UT 84620-7607',
#   'BI6500 - Antelope Island Bison'],
#  ['Ryan F Harper',
#   '5 - Unsuccessful',
#   '3376 S Cooper St',
#   'Syracuse UT 84075-1102',
#   'BI6500 - Antelope Island Bison'],
#  ['Royce K Harrop',
#   '5 - Unsuccessful',
#   '820 S 200 E',
#   'Layton UT 84041-4160',
#   'BI6500 - Antelope Island Bison'],
#  ['COLTON R HAWKER',
#   '5 - Unsuccessful',
#   '360 S 200 E',
#   'Wellsville UT 84339-9781',
#   'BI6500 - Antelope Island Bison'],
#  ['DALE R HEIZER',
#   '5 - Unsuccessful',
#   '445 S Sunset Dr',
#   'Kaysville UT 84037-9669',
#   'BI6500 - Antelope Island Bison'],
#  ['ANDREW J HERNANDEZ',
#   '5 - Unsuccessful',
#   '9958 S Tulip Dr',
#   'Sandy UT 84094-3914',
#   'BI6500 - Antelope Island Bison'],
#  ['ROBERT S HEWLETT',
#   '5 - Unsuccessful',
#   '967 W 725 S',
#   'Brigham City UT 84302-2815',
#   'BI6500 - Antelope Island Bison'],
#  ['Chelsea D Hill',
#   '5 - Unsuccessful',
#   '402 Topaz Dr',
#   'Santaquin UT 84655-7244',
#   'BI6500 - Antelope Island Bison'],
#  ['JACOB C HITT',
#   '5 - Unsuccessful',
#   '4253 Porter Ave',
#   'South Ogden UT 84403-2836',
#   'BI6500 - Antelope Island Bison'],
#  ['DONALD L HLAVACEK',
#   '5 - Unsuccessful',
#   '11518 S Tara Woods Ln',
#   'South Jordan UT 84095-8053',
#   'BI6500 - Antelope Island Bison'],
#  ['Chad S Hobbs',
#   '5 - Unsuccessful',
#   '2256 S 100 W',
#   'Clearfield UT 84015-2029',
#   'BI6500 - Antelope Island Bison'],
#  ['DOMINIC L HOBBS',
#   '5 - Unsuccessful',
#   '7963 Douglas Dr',
#   'Park City UT 84098-5181',
#   'BI6500 - Antelope Island Bison'],
#  ['MARY L HOLDSWORTH',
#   '5 - Unsuccessful',
#   '528 W 1150 S',
#   'Payson UT 84651-5630',
#   'BI6500 - Antelope Island Bison'],
#  ['IVAN J HOOLEY',
#   '5 - Unsuccessful',
#   '545 W 600 S',
#   'Bountiful UT 84010-8354',
#   'BI6500 - Antelope Island Bison'],
#  ['ALLIE P HOTH',
#   '5 - Unsuccessful',
#   '707B Meadow Lark Ln',
#   'Smithfield UT 84335-1003',
#   'BI6500 - Antelope Island Bison'],
#  ['Blake P Hoth',
#   '5 - Unsuccessful',
#   '442 E Sandy Woods Ln',
#   'Midvale UT 84047-4904',
#   'BI6500 - Antelope Island Bison'],
#  ['JOSEPH E HOWE',
#   '5 - Unsuccessful',
#   '180 E 800 S',
#   'Ephraim UT 84627-1500',
#   'BI6500 - Antelope Island Bison'],
#  ['WILFREDO O HUAMAN',
#   '5 - Unsuccessful',
#   '620 N Orchard Dr Unit 39',
#   'North Salt Lake UT 84010-8563',
#   'BI6500 - Antelope Island Bison'],
#  ['Benjamin W Hulet',
#   '5 - Unsuccessful',
#   '2671 E 3430 S',
#   'Saint George UT 84790-6180',
#   'BI6500 - Antelope Island Bison'],
#  ['JOSEPH A HUNTER',
#   '5 - Unsuccessful',
#   '4486 S Vista Montana Way',
#   'West Valley UT 84128-5504',
#   'BI6500 - Antelope Island Bison'],
#  ['TIFFANY IRVINE',
#   '5 - Unsuccessful',
#   '322 S 1675 E',
#   'Springville UT 84663-2746',
#   'BI6500 - Antelope Island Bison'],
#  ['Glen G Jenkins',
#   '5 - Unsuccessful',
#   '972 S 1100 W',
#   'Woods Cross UT 84087-2026',
#   'BI6500 - Antelope Island Bison'],
#  ['Jacob G Jenkins',
#   '5 - Unsuccessful',
#   '711 W 1950 S',
#   'Syracuse UT 84075-9451',
#   'BI6500 - Antelope Island Bison'],
#  ['BRIAN L JENSON',
#   '5 - Unsuccessful',
#   'HC 60 Box 216',
#   'Rocky Ridge UT 84645-9806',
#   'BI6500 - Antelope Island Bison'],
#  ['Nathan Johanson',
#   '5 - Unsuccessful',
#   '2484 W 1800 N',
#   'Clinton UT 84015-7930',
#   'BI6500 - Antelope Island Bison'],
#  ['Andrew B Johnson',
#   '5 - Unsuccessful',
#   '659 E Cedar Hollow Rd',
#   'Lehi UT 84043-3517',
#   'BI6500 - Antelope Island Bison'],
#  ['JEREMIAH T JOHNSON',
#   '5 - Unsuccessful',
#   '6620 N Clear Water Cir',
#   'Stansbury Park UT 84074-5503',
#   'BI6500 - Antelope Island Bison'],
#  ['Steve B Johnson',
#   '5 - Unsuccessful',
#   '950 E 2125 N',
#   'Lehi UT 84043-3064',
#   'BI6500 - Antelope Island Bison'],
#  ['KELLY G JONES',
#   '5 - Unsuccessful',
#   '10333 S Weeping Willow Dr',
#   'Sandy UT 84070-4245',
#   'BI6500 - Antelope Island Bison'],
#  ['ZACHERY C JONES',
#   '5 - Unsuccessful',
#   '130 N 1120 E',
#   'Springville UT 84663-1782',
#   'BI6500 - Antelope Island Bison'],
#  ['David R JORDAN',
#   '5 - Unsuccessful',
#   '357 W Millcreek Cir',
#   'Washington UT 84780-1522',
#   'BI6500 - Antelope Island Bison'],
#  ['KIMBERLY JULIAN',
#   '5 - Unsuccessful',
#   'PO Box 273',
#   'Stockton UT 84071-0273',
#   'BI6500 - Antelope Island Bison'],
#  ['RANDY S JULIAN',
#   '5 - Unsuccessful',
#   'PO Box 273',
#   'Stockton UT 84071-0273',
#   'BI6500 - Antelope Island Bison'],
#  ['MICHAEL R KASSAHN',
#   '5 - Unsuccessful',
#   '9 Park Place Ln',
#   'Centerville UT 84014-1834',
#   'BI6500 - Antelope Island Bison'],
#  ['ZACHARY K KEARL',
#   '5 - Unsuccessful',
#   '51 S Mustang Ridge Rd',
#   'Grantsville UT 84029-5030',
#   'BI6500 - Antelope Island Bison'],
#  ['COLE C KELLEY',
#   '5 - Unsuccessful',
#   '1841 S Cameron Dr',
#   'West Haven UT 84401-8463',
#   'BI6500 - Antelope Island Bison'],
#  ['KAYLA B KELLEY',
#   '5 - Unsuccessful',
#   '1841 S Cameron Dr',
#   'West Haven UT 84401-8463',
#   'BI6500 - Antelope Island Bison'],
#  ['LUISE KELSON',
#   '5 - Unsuccessful',
#   '2998 S Perennial Ct',
#   'Magna UT 84044-3216',
#   'BI6500 - Antelope Island Bison'],
#  ['COLEMAN A KENDRICK',
#   '5 - Unsuccessful',
#   '5954 W Birch Water Ln',
#   'West Jordan UT 84081-5739',
#   'BI6500 - Antelope Island Bison'],
#  ['Robert C Kendrick',
#   '5 - Unsuccessful',
#   '825 S 225 E',
#   'Providence UT 84332-9864',
#   'BI6500 - Antelope Island Bison'],
#  ['COLTON D KERSHAW',
#   '5 - Unsuccessful',
#   '871 S West Hoytsville Rd',
#   'Coalville UT 84017-9762',
#   'BI6500 - Antelope Island Bison'],
#  ['Larry D Kesler',
#   '5 - Unsuccessful',
#   '2485 W 7625 S',
#   'West Jordan UT 84084-3867',
#   'BI6500 - Antelope Island Bison'],
#  ['TOM S KING',
#   '5 - Unsuccessful',
#   '826 S Black Canyon Rd',
#   'Antimony UT 84712-7730',
#   'BI6500 - Antelope Island Bison'],
#  ['Daymond R Kofford',
#   '5 - Unsuccessful',
#   '2069 E Susan Way',
#   'Cottonwood UT 84121-3737',
#   'BI6500 - Antelope Island Bison'],
#  ['NICHOLAS J KONCAR',
#   '5 - Unsuccessful',
#   '3478 E Bougival Ln',
#   'Cottonwood Heights UT 84093-1208',
#   'BI6500 - Antelope Island Bison'],
#  ['ADAM KROGH',
#   '5 - Unsuccessful',
#   '242 N 1400 W',
#   'Clearfield UT 84015-8646',
#   'BI6500 - Antelope Island Bison'],
#  ['MICHAEL O LALLAS',
#   '5 - Unsuccessful',
#   '284 E 400 S',
#   'Orem UT 84058-6312',
#   'BI6500 - Antelope Island Bison'],
#  ['MICHAEL E LAMB',
#   '5 - Unsuccessful',
#   '944 E Murdock Dr',
#   'Pleasant Grove UT 84062-4564',
#   'BI6500 - Antelope Island Bison'],
#  ['STEWART R LAY',
#   '5 - Unsuccessful',
#   '5994 S Susquehanna',
#   'Murray UT 84123-5527',
#   'BI6500 - Antelope Island Bison'],
#  ['DILLON M LEE',
#   '5 - Unsuccessful',
#   '1464 W 1920 N',
#   'Layton UT 84041-1104',
#   'BI6500 - Antelope Island Bison'],
#  ['MICHAEL E LEWIS',
#   '5 - Unsuccessful',
#   '44 E Magellan Ln',
#   'Elk Ridge UT 84651-5672',
#   'BI6500 - Antelope Island Bison'],
#  ['MADISON R LINDSEY',
#   '5 - Unsuccessful',
#   '1046 S 900 E Apt B',
#   'Slc UT 84105-1340',
#   'BI6500 - Antelope Island Bison'],
#  ['ASPEN M LOZANO',
#   '5 - Unsuccessful',
#   '39 S 200 W',
#   'Minersville UT 84752-7764',
#   'BI6500 - Antelope Island Bison'],
#  ['Brian D Lund',
#   '5 - Unsuccessful',
#   '510 E Canyon Rim Rd',
#   'Smithfield UT 84335-3106',
#   'BI6500 - Antelope Island Bison'],
#  ['Cole Manning',
#   '5 - Unsuccessful',
#   '4783 W 700 S',
#   'West Point UT 84015-6819',
#   'BI6500 - Antelope Island Bison'],
#  ['ALEXANDER R MARSHALL',
#   '5 - Unsuccessful',
#   '12125 N 9200 W',
#   'Tremonton UT 84337-9512',
#   'BI6500 - Antelope Island Bison'],
#  ['BURTON W MAY',
#   '5 - Unsuccessful',
#   '2360 S 900 W',
#   'Syracuse UT 84075-9172',
#   'BI6500 - Antelope Island Bison'],
#  ['JASON D MCCOLLIN',
#   '5 - Unsuccessful',
#   '290 S Main St',
#   'Glenwood UT 84730-7771',
#   'BI6500 - Antelope Island Bison'],
#  ['CHASE J MCDERMOTT',
#   '5 - Unsuccessful',
#   '6610 W Highway 83',
#   'Corinne UT 84307-9756',
#   'BI6500 - Antelope Island Bison'],
#  ['MCKAY MCFARLAND',
#   '5 - Unsuccessful',
#   '5216 S 6050 W',
#   'Hooper UT 84315-9559',
#   'BI6500 - Antelope Island Bison'],
#  ['Bryant R McKay',
#   '5 - Unsuccessful',
#   '570 W 100 S',
#   'Smithfield UT 84335-2210',
#   'BI6500 - Antelope Island Bison'],
#  ['JACOB E MCMILLIN',
#   '5 - Unsuccessful',
#   '111 W 3100 S',
#   'Bountiful UT 84010-6521',
#   'BI6500 - Antelope Island Bison'],
#  ['CHARLES D MCPHEE',
#   '5 - Unsuccessful',
#   '1423 N Quincy Ave',
#   'Ogden UT 84404-3436',
#   'BI6500 - Antelope Island Bison'],
#  ['ERIC A MEACHAM',
#   '5 - Unsuccessful',
#   '5425 N Enoch Rd',
#   'Enoch UT 84721-7628',
#   'BI6500 - Antelope Island Bison'],
#  ['richard d mears',
#   '5 - Unsuccessful',
#   '767 Country Clb',
#   'Stansbury Park UT 84074-9625',
#   'BI6500 - Antelope Island Bison'],
#  ['STEVEN L MELNICK',
#   '5 - Unsuccessful',
#   '2458 N 3550 W',
#   'Plain City UT 84404-9120',
#   'BI6500 - Antelope Island Bison'],
#  ['CLAYTON MEYER',
#   '5 - Unsuccessful',
#   '35 WEST CANYON RD',
#   'MAYFIELD UT 84643',
#   'BI6500 - Antelope Island Bison'],
#  ['JOHANN B MEYER',
#   '5 - Unsuccessful',
#   '723 S 1850 E',
#   'Spanish Fork UT 84660-2704',
#   'BI6500 - Antelope Island Bison'],
#  ['MARSHALL A MIKUCKI',
#   '5 - Unsuccessful',
#   '867 E 100 N',
#   'Spanish Fork UT 84660-1931',
#   'BI6500 - Antelope Island Bison'],
#  ['Chandler D Miller',
#   '5 - Unsuccessful',
#   '3595 S 2700 W',
#   'West Haven UT 84401-8425',
#   'BI6500 - Antelope Island Bison'],
#  ['Danny Monnett',
#   '5 - Unsuccessful',
#   'PO Box 107',
#   'Kanab UT 84741-0107',
#   'BI6500 - Antelope Island Bison'],
#  ['MITCHELL J MOORE',
#   '5 - Unsuccessful',
#   '2937 W 3835 S',
#   'West Valley City UT 84119-4557',
#   'BI6500 - Antelope Island Bison'],
#  ['RAYMOND P MORRISON',
#   '5 - Unsuccessful',
#   '722 Moon Cir',
#   'Farmington UT 84025-3917',
#   'BI6500 - Antelope Island Bison'],
#  ['Gary A Mulvey',
#   '5 - Unsuccessful',
#   '405 Carol Dr',
#   'Layton UT 84041-4272',
#   'BI6500 - Antelope Island Bison'],
#  ['JACOB T MURPHY',
#   '5 - Unsuccessful',
#   '1932 W Pointe Meadow Loop',
#   'Lehi UT 84043-4956',
#   'BI6500 - Antelope Island Bison'],
#  ['MARK D MURRAY',
#   '5 - Unsuccessful',
#   '1652 S 2425 W',
#   'West Haven UT 84401-6772',
#   'BI6500 - Antelope Island Bison'],
#  ['Anthony J Nelson',
#   '5 - Unsuccessful',
#   '11905 S Powder Cv',
#   'Herriman UT 84096-7738',
#   'BI6500 - Antelope Island Bison'],
#  ['Lindsey A Nelson',
#   '5 - Unsuccessful',
#   '649 W 2225 S',
#   'Syracuse UT 84075-9194',
#   'BI6500 - Antelope Island Bison'],
#  ['Preston C Nelson',
#   '5 - Unsuccessful',
#   '649 W 2225 S',
#   'Syracuse UT 84075-9194',
#   'BI6500 - Antelope Island Bison'],
#  ['JASON J NIELSON',
#   '5 - Unsuccessful',
#   '1040 W 275 S',
#   'Tremonton UT 84337-1751',
#   'BI6500 - Antelope Island Bison'],
#  ['CHRIS K NIEMANN',
#   '5 - Unsuccessful',
#   '550 pheasant hollow',
#   'LOGAN UT 84325',
#   'BI6500 - Antelope Island Bison'],
#  ['CADEN C Norris',
#   '5 - Unsuccessful',
#   '2193 W 2550 S',
#   'West Haven UT 84401-1035',
#   'BI6500 - Antelope Island Bison'],
#  ['TRISTAN P ADAMS',
#   '5 - Unsuccessful',
#   '3478 S Cozy River Pl Apt \n409',
#   'West Valley City UT \n84119-4507',
#   'BI6500 - Antelope Island Bison'],
#  ['CRAIG D ADAMSON',
#   '5 - Unsuccessful',
#   '2865 W 1425 N',
#   'Layton UT \n84041-3453',
#   'BI6500 - Antelope Island Bison'],
#  ['Greg D Allsop',
#   '5 - Unsuccessful',
#   '902 W 2075 S',
#   'Syracuse UT \n84075-9163',
#   'BI6500 - Antelope Island Bison'],
#  ['Justin G Alvey',
#   '5 - Unsuccessful',
#   'PO Box 570096',
#   'Sigurd UT 84657-0096',
#   'BI6500 - Antelope Island Bison'],
#  ['PAMELA S ANDERSON',
#   '5 - Unsuccessful',
#   '6445 S 1600 W',
#   'Hyrum UT 84319-7101',
#   'BI6500 - Antelope Island Bison'],
#  ['JEFF C ANDREWS',
#   '5 - Unsuccessful',
#   '53 S 1st St',
#   'Tooele UT 84074-2114',
#   'BI6500 - Antelope Island Bison'],
#  ['RONALD S ARRINGTON',
#   '5 - Unsuccessful',
#   '322 W 1250 N',
#   'Centerville UT \n84014-1102',
#   'BI6500 - Antelope Island Bison'],
#  ['JAY S ATKINS',
#   '5 - Unsuccessful',
#   '8567 S Maul Oak Dr',
#   'West Jordan UT \n84081-1847',
#   'BI6500 - Antelope Island Bison'],
#  ['JOSHUA D AZERA',
#   '5 - Unsuccessful',
#   '8399 S 3200 W',
#   'West Jordan UT \n84088-5222',
#   'BI6500 - Antelope Island Bison'],
#  ['BRANDON L BAKER',
#   '5 - Unsuccessful',
#   '4046 W Adler Rd',
#   'Riverton UT \n84096-1245',
#   'BI6500 - Antelope Island Bison'],
#  ['Jordan Y Baker',
#   '5 - Unsuccessful',
#   '6488 W Bridge Maple Ln',
#   'West Jordan UT \n84081-4168',
#   'BI6500 - Antelope Island Bison'],
#  ['Jarom B Bangerter',
#   '5 - Unsuccessful',
#   '665 E 200 S',
#   'Heber City UT \n84032-2142',
#   'BI6500 - Antelope Island Bison'],
#  ['Byron W Barker',
#   '5 - Unsuccessful',
#   '5385 W 8800 N',
#   'Tremonton UT \n84337-8648',
#   'BI6500 - Antelope Island Bison'],
#  ['GAVIN M BARLOW',
#   '5 - Unsuccessful',
#   '4661 N 25 E',
#   'Enoch UT 84721-7485',
#   'BI6500 - Antelope Island Bison'],
#  ['Jason M Barlow',
#   '5 - Unsuccessful',
#   '4661 N 25 E',
#   'Enoch UT 84721-7485',
#   'BI6500 - Antelope Island Bison'],
#  ['Ryan N Barney',
#   '5 - Unsuccessful',
#   '11091 S Windy Peak \nRidge Dr',
#   'Sandy UT 84094-5445',
#   'BI6500 - Antelope Island Bison'],
#  ['KYLEE R BARRETT',
#   '5 - Unsuccessful',
#   '465 N 3550 W',
#   'Layton UT \n84041-3712',
#   'BI6500 - Antelope Island Bison'],
#  ['Jacob J Bawden',
#   '5 - Unsuccessful',
#   '13208 S 2420 W',
#   'Riverton UT \n84065-2234',
#   'BI6500 - Antelope Island Bison'],
#  ['Brock M Bean',
#   '5 - Unsuccessful',
#   '11492 N Maple Hollow Ct',
#   'Highland UT \n84003-5635',
#   'BI6500 - Antelope Island Bison'],
#  ['Alex B Bench',
#   '5 - Unsuccessful',
#   '1754 N 1770 E',
#   'Mapleton UT \n84664-4128',
#   'BI6500 - Antelope Island Bison'],
#  ['karen berthold',
#   '5 - Unsuccessful',
#   '1230 Northridge Dr',
#   'Bountiful UT \n84010-1710',
#   'BI6500 - Antelope Island Bison'],
#  ['STEPHEN E BIALKOWSKI',
#   '5 - Unsuccessful',
#   '121 N 300 E',
#   'Hyde Park UT \n84318-3419',
#   'BI6500 - Antelope Island Bison'],
#  ['Jack S Bishop',
#   '5 - Unsuccessful',
#   '468 E Ridgeview Cir',
#   'Ivins UT 84738-6738',
#   'BI6500 - Antelope Island Bison'],
#  ['MASON E BLACKHAM',
#   '5 - Unsuccessful',
#   '253 N 780 E',
#   'Salem UT 84653-5532',
#   'BI6500 - Antelope Island Bison'],
#  ['MORGAN N BLACKHAM',
#   '5 - Unsuccessful',
#   '253 N 780 E',
#   'Salem UT 84653-5532',
#   'BI6500 - Antelope Island Bison'],
#  ['Steven P Blackhurst',
#   '5 - Unsuccessful',
#   '10173 N Mystic Holw',
#   'Highland UT \n84003-2610',
#   'BI6500 - Antelope Island Bison'],
#  ['Layne H Blake',
#   '5 - Unsuccessful',
#   '2676 W 3900 S',
#   'Roy UT 84067-9694',
#   'BI6500 - Antelope Island Bison'],
#  ['BROOKE BOHRER',
#   '5 - Unsuccessful',
#   '2429 W 2075 N',
#   'Clinton UT \n84015-7661',
#   'BI6500 - Antelope Island Bison'],
#  ['GERALD G BOYER',
#   '5 - Unsuccessful',
#   '5925 S 1075 E',
#   'Ogden UT 84405-4915',
#   'BI6500 - Antelope Island Bison'],
#  ['Larry D Bringhurst',
#   '5 - Unsuccessful',
#   '405 E 1200 N',
#   'Mapleton UT \n84664-3704',
#   'BI6500 - Antelope Island Bison'],
#  ['TAYLAR BRITTAIN',
#   '5 - Unsuccessful',
#   '1457 S 2950 E',
#   'Spanish Fork UT \n84660-3110',
#   'BI6500 - Antelope Island Bison'],
#  ['Donald L Brown',
#   '5 - Unsuccessful',
#   'PO Box 219',
#   'Hinckley UT \n84635-0219',
#   'BI6500 - Antelope Island Bison'],
#  ['MATTHEW R BROWN',
#   '5 - Unsuccessful',
#   '12827 S Tortoise Ln',
#   'Riverton UT \n84096-5500',
#   'BI6500 - Antelope Island Bison'],
#  ['SAGE M BROWN',
#   '5 - Unsuccessful',
#   '510 N 100 W',
#   'Kanab UT 84741-3255',
#   'BI6500 - Antelope Island Bison'],
#  ['James R Bruce',
#   '5 - Unsuccessful',
#   '926 E Statice Ave',
#   'Sandy UT 84094-4506',
#   'BI6500 - Antelope Island Bison'],
#  ['ZACHARY P BRYANT',
#   '5 - Unsuccessful',
#   '426 N Locust Ave',
#   'Lindon UT 84042-1313',
#   'BI6500 - Antelope Island Bison'],
#  ['MARY E BURBANK',
#   '5 - Unsuccessful',
#   '6248 W Center St',
#   'Mendon UT \n84325-9747',
#   'BI6500 - Antelope Island Bison'],
#  ['Danielle M Burgener',
#   '5 - Unsuccessful',
#   '3743 W Salinas Dr',
#   'Riverton UT \n84065-7637',
#   'BI6500 - Antelope Island Bison'],
#  ['DALLIN BUTLER',
#   '5 - Unsuccessful',
#   '3089 E Sandpiper Rd',
#   'Eagle Mountain UT \n84005-6117',
#   'BI6500 - Antelope Island Bison'],
#  ['BAILEY J CALDER',
#   '5 - Unsuccessful',
#   '1504 E Pheasant Run Dr',
#   'Springville UT \n84663-3826',
#   'BI6500 - Antelope Island Bison'],
#  ['BRIDGET CALDER',
#   '5 - Unsuccessful',
#   '1504 E Pheasant Run Dr',
#   'Springville UT \n84663-3826',
#   'BI6500 - Antelope Island Bison'],
#  ['TASIA L CARSON',
#   '5 - Unsuccessful',
#   '1562 W 590 N',
#   'Lindon UT 84042-2079',
#   'BI6500 - Antelope Island Bison'],
#  ['WYATT R CARVER',
#   '5 - Unsuccessful',
#   '5641 N Fork Rd',
#   'Eden UT 84310-9685',
#   'BI6500 - Antelope Island Bison'],
#  ['RUSSELL B CASE',
#   '5 - Unsuccessful',
#   '2504 W Main Canyon Rd',
#   'Wallsburg UT \n84082-9740',
#   'BI6500 - Antelope Island Bison'],
#  ['RYLAN CEDARSTROM',
#   '5 - Unsuccessful',
#   '174 W 300 S',
#   'Midway UT \n84049-6512',
#   'BI6500 - Antelope Island Bison'],
#  ['CHARLES V CHADWICK JR',
#   '5 - Unsuccessful',
#   '1232 S 775 E',
#   'Ogden UT 84404-5826',
#   'BI6500 - Antelope Island Bison'],
#  ['RICARDO L CHASTAIN',
#   '5 - Unsuccessful',
#   '1194 E Black Brush Dr',
#   'Washington UT \n84780-2568',
#   'BI6500 - Antelope Island Bison'],
#  ['ZACHARY E CHATWIN',
#   '5 - Unsuccessful',
#   '418 W 500 S',
#   'Payson UT \n84651-2708',
#   'BI6500 - Antelope Island Bison'],
#  ['Andrew D Christensen',
#   '5 - Unsuccessful',
#   '2718 S 450 E',
#   'Bountiful UT \n84010-4317',
#   'BI6500 - Antelope Island Bison'],
#  ['ROGER L CHRISTENSEN',
#   '5 - Unsuccessful',
#   '691 3 O Clock Dr',
#   'Tooele UT 84074-2593',
#   'BI6500 - Antelope Island Bison'],
#  ['Scott B Christensen',
#   '5 - Unsuccessful',
#   '967 W Fremont Ave',
#   'Salt Lake City UT \n84104-2006',
#   'BI6500 - Antelope Island Bison'],
#  ['Taylor B Christensen',
#   '5 - Unsuccessful',
#   '2775 E Westerling Way',
#   'Cottonwood Heights \nUT 84121-5239',
#   'BI6500 - Antelope Island Bison'],
#  ['JASON F CLEGG',
#   '5 - Unsuccessful',
#   '884 E Kaseys Cir',
#   'Draper UT 84020-7611',
#   'BI6500 - Antelope Island Bison'],
#  ['CEDAR C COBURN',
#   '5 - Unsuccessful',
#   '708 S State St',
#   'Genola UT \n84655-6089',
#   'BI6500 - Antelope Island Bison'],
#  ['NICHOLAS P COCHRAN',
#   '5 - Unsuccessful',
#   '6544 W Haven Maple Dr',
#   'West Jordan UT \n84081-4162',
#   'BI6500 - Antelope Island Bison'],
#  ['MARK S COLLARD',
#   '5 - Unsuccessful',
#   '4858 W 5500 S',
#   'Hooper UT \n84315-9515',
#   'BI6500 - Antelope Island Bison'],
#  ['SHANNON M COLTON',
#   '5 - Unsuccessful',
#   '982 W Porter Ln',
#   'West Bountiful UT \n84087-2403',
#   'BI6500 - Antelope Island Bison'],
#  ['RYAN D CONRAD',
#   '5 - Unsuccessful',
#   '973 W 1500 S',
#   'Springville UT \n84663-5920',
#   'BI6500 - Antelope Island Bison'],
#  ['KASH M COOK',
#   '5 - Unsuccessful',
#   'PO Box 518',
#   'Moroni UT \n84646-0518',
#   'BI6500 - Antelope Island Bison'],
#  ['PHILLIP J COOK',
#   '5 - Unsuccessful',
#   'PO Box 518',
#   'Moroni UT \n84646-0518',
#   'BI6500 - Antelope Island Bison'],
#  ['ALEX P COOMBS',
#   '5 - Unsuccessful',
#   '1283 W Johnson Ridge Ln',
#   'West Jordan UT \n84084-3580',
#   'BI6500 - Antelope Island Bison'],
#  ['BRETT M COOMBS',
#   '5 - Unsuccessful',
#   '362 W 2030 N',
#   'Tooele UT 84074-3743',
#   'BI6500 - Antelope Island Bison'],
#  ['Robert A Cox',
#   '5 - Unsuccessful',
#   '1438 N 1350 W',
#   'Farr West UT \n84404-3483',
#   'BI6500 - Antelope Island Bison'],
#  ['AYDEN C DABB',
#   '5 - Unsuccessful',
#   '5060 Vista Dr',
#   'Roy UT 84067-7707',
#   'BI6500 - Antelope Island Bison'],
#  ['MATTHEW DAVIS',
#   '5 - Unsuccessful',
#   '6141 W Cherry Springs Ct',
#   'Salt Lake City UT \n84118-9303',
#   'BI6500 - Antelope Island Bison'],
#  ['KYLE F DAY',
#   '5 - Unsuccessful',
#   '512 Church St',
#   'Layton UT 84041-3112',
#   'BI6500 - Antelope Island Bison'],
#  ['WYATT C DESPAIN',
#   '5 - Unsuccessful',
#   '5054 W ARIENE LANE',
#   'SALT LAKE CITY UT \n84120',
#   'BI6500 - Antelope Island Bison'],
#  ['CURTIS M DEYOUNG',
#   '5 - Unsuccessful',
#   '3751 W Ridges Rd',
#   'Morgan UT \n84050-8707',
#   'BI6500 - Antelope Island Bison'],
#  ['TONIA J DOWNWARD',
#   '5 - Unsuccessful',
#   '652 S Hale St',
#   'Grantsville UT \n84029-9673',
#   'BI6500 - Antelope Island Bison'],
#  ['Daniel W Draper',
#   '5 - Unsuccessful',
#   '5707 W 10620 N',
#   'Highland UT \n84003-9125',
#   'BI6500 - Antelope Island Bison'],
#  ['Brandon M Dutson',
#   '5 - Unsuccessful',
#   '1454 Wallace Dr',
#   'Springville UT \n84663-3509',
#   'BI6500 - Antelope Island Bison'],
#  ['Tony R Earley',
#   '5 - Unsuccessful',
#   'PO Box 212',
#   'Laketown UT \n84038-0212',
#   'BI6500 - Antelope Island Bison'],
#  ['MARKEE EGGETT',
#   '5 - Unsuccessful',
#   '838 W 3300 N',
#   'Pleasant Grove UT \n84062-8758',
#   'BI6500 - Antelope Island Bison'],
#  ['Deena K Ericksen',
#   '5 - Unsuccessful',
#   '8340 W 3680 S',
#   'Magna UT \n84044-2292',
#   'BI6500 - Antelope Island Bison'],
#  ['DALLAS j ESKELSON',
#   '5 - Unsuccessful',
#   '5824 W Moon Shadow Dr',
#   'Herriman UT \n84096-1775',
#   'BI6500 - Antelope Island Bison'],
#  ['Charles S Evans',
#   '5 - Unsuccessful',
#   '915 N 600 W',
#   'West Bountiful UT \n84087-1338',
#   'BI6500 - Antelope Island Bison'],
#  ['JACK A EVANS',
#   '5 - Unsuccessful',
#   '14847S S Redwood Rd',
#   'Bluffdale UT \n84065-3736',
#   'BI6500 - Antelope Island Bison'],
#  ['MORGAN L EWELL',
#   '5 - Unsuccessful',
#   '5743 W 12815 S',
#   'Herriman UT \n84096-8965',
#   'BI6500 - Antelope Island Bison'],
#  ['TAMERA J FARR',
#   '5 - Unsuccessful',
#   '256 W 2600 N',
#   'Lehi UT 84043-3360',
#   'BI6500 - Antelope Island Bison'],
#  ['BRIAN FIRTH',
#   '5 - Unsuccessful',
#   '1321 S 840 W',
#   'Woods Cross UT \n84087-2000',
#   'BI6500 - Antelope Island Bison'],
#  ['HENNING P FISCHER',
#   '5 - Unsuccessful',
#   '473 Emery Ave',
#   'Orem UT 84057-3725',
#   'BI6500 - Antelope Island Bison'],
#  ['ALEXIS FISHER',
#   '5 - Unsuccessful',
#   '6817 S 375 E',
#   'South Weber UT \n84405-7244',
#   'BI6500 - Antelope Island Bison'],
#  ['AUBREY D FOGARTY',
#   '5 - Unsuccessful',
#   '1214 E Harvard Ave',
#   'Salt Lake City UT \n84105-1906',
#   'BI6500 - Antelope Island Bison'],
#  ['Michael N France',
#   '5 - Unsuccessful',
#   '288 S House Rock Cir',
#   'Cedar City UT \n84720-6723',
#   'BI6500 - Antelope Island Bison'],
#  ['Darren R Franz',
#   '5 - Unsuccessful',
#   '2610 W Pine Meadow Pl',
#   'Salt Lake City UT \n84129-1556',
#   'BI6500 - Antelope Island Bison'],
#  ['KIM E FULLER',
#   '5 - Unsuccessful',
#   '1711 W River View Dr',
#   'Bluffdale UT \n84065-3772',
#   'BI6500 - Antelope Island Bison'],
#  ['JACOB M GALLEGOS',
#   '5 - Unsuccessful',
#   '4670 S 6300 W',
#   'Hooper UT \n84315-9742',
#   'BI6500 - Antelope Island Bison'],
#  ['JOSHUA L GALLEGOS',
#   '5 - Unsuccessful',
#   '4670 S 6300 W',
#   'Hooper UT \n84315-9742',
#   'BI6500 - Antelope Island Bison'],
#  ['Megan R Gallegos',
#   '5 - Unsuccessful',
#   '4670 S 6300 W',
#   'Hooper UT \n84315-9742',
#   'BI6500 - Antelope Island Bison'],
#  ['Nathan M Gallegos',
#   '5 - Unsuccessful',
#   '3662 Rose Springs Rd',
#   'Tooele UT 84074-5517',
#   'BI6500 - Antelope Island Bison'],
#  ['Richard M Gallegos',
#   '5 - Unsuccessful',
#   '4670 S 6300 W',
#   'Hooper UT \n84315-9742',
#   'BI6500 - Antelope Island Bison'],
#  ['GEORGE D GAREE',
#   '5 - Unsuccessful',
#   '9962 S Eden Ridge Dr',
#   'South Jordan UT \n84095-3016',
#   'BI6500 - Antelope Island Bison'],
#  ['LEONARD B GAREE',
#   '5 - Unsuccessful',
#   '9962 S Eden Ridge Dr',
#   'South Jordan UT \n84095-3016',
#   'BI6500 - Antelope Island Bison'],
#  ['CLUFF M GIBSON',
#   '5 - Unsuccessful',
#   '14084 S Lewiston Peak Dr',
#   'Herriman UT \n84096-6411',
#   'BI6500 - Antelope Island Bison'],
#  ['VAL D GIBSON',
#   '5 - Unsuccessful',
#   '251 W 255 S',
#   'Orem UT 84058-5469',
#   'BI6500 - Antelope Island Bison'],
#  ['SAWYER R GILES',
#   '5 - Unsuccessful',
#   '1004 E Scenic Dr',
#   'Spanish Fork UT \n84660-2921',
#   'BI6500 - Antelope Island Bison'],
#  ['GREG R GRIFFITH',
#   '5 - Unsuccessful',
#   '8328 W Alpha Dr',
#   'Magna UT \n84044-3013',
#   'BI6500 - Antelope Island Bison'],
#  ['Sidney T Grimes',
#   '5 - Unsuccessful',
#   '3794 W 4525 S',
#   'West Haven UT \n84401-8481',
#   'BI6500 - Antelope Island Bison'],
#  ['MARK S GUNNELL',
#   '5 - Unsuccessful',
#   '175 E 200 N',
#   'Providence UT \n84332-9607',
#   'BI6500 - Antelope Island Bison'],
#  ['ARCADIA HABEL',
#   '5 - Unsuccessful',
#   '493 E Calinas Creek Cir',
#   'Murray UT \n84107-6600',
#   'BI6500 - Antelope Island Bison'],
#  ['RICHARD HABEL',
#   '5 - Unsuccessful',
#   '493 E Calinas Creek Cir',
#   'Murray UT \n84107-6600',
#   'BI6500 - Antelope Island Bison'],
#  ['Steven R Habel',
#   '5 - Unsuccessful',
#   '5098 S Honey Clover Ct',
#   'Murray UT \n84123-8422',
#   'BI6500 - Antelope Island Bison'],
#  ['Barry K Hallsted',
#   '5 - Unsuccessful',
#   '10262 N Honeycut Cir',
#   'Cedar Hills UT \n84062-8654',
#   'BI6500 - Antelope Island Bison'],
#  ['ALEX T HALSTEAD',
#   '5 - Unsuccessful',
#   '4754 E Silver Mountain \nRoad N',
#   'Eagle Mountain UT \n84005',
#   'BI6500 - Antelope Island Bison'],
#  ['THOMAS A HALSTEAD',
#   '5 - Unsuccessful',
#   '25 E Ann Arbor Dr',
#   'Draper UT 84020-3417',
#   'BI6500 - Antelope Island Bison'],
#  ['Thomas M Halstead',
#   '5 - Unsuccessful',
#   '25 E Ann Arbor Dr',
#   'Draper UT 84020-3417',
#   'BI6500 - Antelope Island Bison'],
#  ['DAVID J HALVERSON',
#   '5 - Unsuccessful',
#   '1860 Malan Ct',
#   'Ogden UT 84403-0564',
#   'BI6500 - Antelope Island Bison'],
#  ['KENNETH HAMMON',
#   '5 - Unsuccessful',
#   'PO Box 94',
#   'Richmond UT \n84333-0094',
#   'BI6500 - Antelope Island Bison'],
#  ['Braiden M Hampton',
#   '5 - Unsuccessful',
#   '1375 N 1750 W',
#   'Provo UT 84604-2285',
#   'BI6500 - Antelope Island Bison'],
#  ['Aaron D Hansen',
#   '5 - Unsuccessful',
#   '265 W Kays Dr',
#   'Kaysville UT \n84037-6791',
#   'BI6500 - Antelope Island Bison'],
#  ['david R Hansen',
#   '5 - Unsuccessful',
#   '855 S 200 E',
#   'Santaquin UT \n84655-5582',
#   'BI6500 - Antelope Island Bison'],
#  ['DEVON C HANSEN',
#   '5 - Unsuccessful',
#   '106 Country Clb',
#   'Stansbury Park UT \n84074-9143',
#   'BI6500 - Antelope Island Bison'],
#  ['KIM D HANSEN',
#   '5 - Unsuccessful',
#   '515 E 400 N',
#   'Salem UT 84653-9235',
#   'BI6500 - Antelope Island Bison'],
#  ['Kirk E Hansen',
#   '5 - Unsuccessful',
#   '4342 S 4580 W',
#   'West Valley UT \n84120-5038',
#   'BI6500 - Antelope Island Bison'],
#  ['Marshall P Hansen',
#   '5 - Unsuccessful',
#   '345 W Center St',
#   'Aurora UT 84620-7607',
#   'BI6500 - Antelope Island Bison'],
#  ['Ryan F Harper',
#   '5 - Unsuccessful',
#   '3376 S Cooper St',
#   'Syracuse UT \n84075-1102',
#   'BI6500 - Antelope Island Bison'],
#  ['Royce K Harrop',
#   '5 - Unsuccessful',
#   '820 S 200 E',
#   'Layton UT \n84041-4160',
#   'BI6500 - Antelope Island Bison'],
#  ['COLTON R HAWKER',
#   '5 - Unsuccessful',
#   '360 S 200 E',
#   'Wellsville UT \n84339-9781',
#   'BI6500 - Antelope Island Bison'],
#  ['DALE R HEIZER',
#   '5 - Unsuccessful',
#   '445 S Sunset Dr',
#   'Kaysville UT \n84037-9669',
#   'BI6500 - Antelope Island Bison'],
#  ['ANDREW J HERNANDEZ',
#   '5 - Unsuccessful',
#   '9958 S Tulip Dr',
#   'Sandy UT 84094-3914',
#   'BI6500 - Antelope Island Bison'],
#  ['ROBERT S HEWLETT',
#   '5 - Unsuccessful',
#   '967 W 725 S',
#   'Brigham City UT \n84302-2815',
#   'BI6500 - Antelope Island Bison'],
#  ['Chelsea D Hill',
#   '5 - Unsuccessful',
#   '402 Topaz Dr',
#   'Santaquin UT \n84655-7244',
#   'BI6500 - Antelope Island Bison'],
#  ['JACOB C HITT',
#   '5 - Unsuccessful',
#   '4253 Porter Ave',
#   'South Ogden UT \n84403-2836',
#   'BI6500 - Antelope Island Bison'],
#  ['DONALD L HLAVACEK',
#   '5 - Unsuccessful',
#   '11518 S Tara Woods Ln',
#   'South Jordan UT \n84095-8053',
#   'BI6500 - Antelope Island Bison'],
#  ['Chad S Hobbs',
#   '5 - Unsuccessful',
#   '2256 S 100 W',
#   'Clearfield UT \n84015-2029',
#   'BI6500 - Antelope Island Bison'],
#  ['DOMINIC L HOBBS',
#   '5 - Unsuccessful',
#   '7963 Douglas Dr',
#   'Park City UT \n84098-5181',
#   'BI6500 - Antelope Island Bison'],
#  ['MARY L HOLDSWORTH',
#   '5 - Unsuccessful',
#   '528 W 1150 S',
#   'Payson UT \n84651-5630',
#   'BI6500 - Antelope Island Bison'],
#  ['IVAN J HOOLEY',
#   '5 - Unsuccessful',
#   '545 W 600 S',
#   'Bountiful UT \n84010-8354',
#   'BI6500 - Antelope Island Bison'],
#  ['ALLIE P HOTH',
#   '5 - Unsuccessful',
#   '707B Meadow Lark Ln',
#   'Smithfield UT \n84335-1003',
#   'BI6500 - Antelope Island Bison'],
#  ['Blake P Hoth',
#   '5 - Unsuccessful',
#   '442 E Sandy Woods Ln',
#   'Midvale UT \n84047-4904',
#   'BI6500 - Antelope Island Bison'],
#  ['JOSEPH E HOWE',
#   '5 - Unsuccessful',
#   '180 E 800 S',
#   'Ephraim UT \n84627-1500',
#   'BI6500 - Antelope Island Bison'],
#  ['WILFREDO O HUAMAN',
#   '5 - Unsuccessful',
#   '620 N Orchard Dr Unit 39',
#   'North Salt Lake UT \n84010-8563',
#   'BI6500 - Antelope Island Bison'],
#  ['Benjamin W Hulet',
#   '5 - Unsuccessful',
#   '2671 E 3430 S',
#   'Saint George UT \n84790-6180',
#   'BI6500 - Antelope Island Bison'],
#  ['JOSEPH A HUNTER',
#   '5 - Unsuccessful',
#   '4486 S Vista Montana \nWay',
#   'West Valley UT \n84128-5504',
#   'BI6500 - Antelope Island Bison'],
#  ['TIFFANY IRVINE',
#   '5 - Unsuccessful',
#   '322 S 1675 E',
#   'Springville UT \n84663-2746',
#   'BI6500 - Antelope Island Bison'],
#  ['Glen G Jenkins',
#   '5 - Unsuccessful',
#   '972 S 1100 W',
#   'Woods Cross UT \n84087-2026',
#   'BI6500 - Antelope Island Bison'],
#  ['Jacob G Jenkins',
#   '5 - Unsuccessful',
#   '711 W 1950 S',
#   'Syracuse UT \n84075-9451',
#   'BI6500 - Antelope Island Bison'],
#  ['BRIAN L JENSON',
#   '5 - Unsuccessful',
#   'HC 60 Box 216',
#   'Rocky Ridge UT \n84645-9806',
#   'BI6500 - Antelope Island Bison'],
#  ['Nathan Johanson',
#   '5 - Unsuccessful',
#   '2484 W 1800 N',
#   'Clinton UT \n84015-7930',
#   'BI6500 - Antelope Island Bison'],
#  ['Andrew B Johnson',
#   '5 - Unsuccessful',
#   '659 E Cedar Hollow Rd',
#   'Lehi UT 84043-3517',
#   'BI6500 - Antelope Island Bison'],
#  ['JEREMIAH T JOHNSON',
#   '5 - Unsuccessful',
#   '6620 N Clear Water Cir',
#   'Stansbury Park UT \n84074-5503',
#   'BI6500 - Antelope Island Bison'],
#  ['Steve B Johnson',
#   '5 - Unsuccessful',
#   '950 E 2125 N',
#   'Lehi UT 84043-3064',
#   'BI6500 - Antelope Island Bison'],
#  ['KELLY G JONES',
#   '5 - Unsuccessful',
#   '10333 S Weeping Willow \nDr',
#   'Sandy UT 84070-4245',
#   'BI6500 - Antelope Island Bison'],
#  ['ZACHERY C JONES',
#   '5 - Unsuccessful',
#   '130 N 1120 E',
#   'Springville UT \n84663-1782',
#   'BI6500 - Antelope Island Bison'],
#  ['David R JORDAN',
#   '5 - Unsuccessful',
#   '357 W Millcreek Cir',
#   'Washington UT \n84780-1522',
#   'BI6500 - Antelope Island Bison'],
#  ['KIMBERLY JULIAN',
#   '5 - Unsuccessful',
#   'PO Box 273',
#   'Stockton UT \n84071-0273',
#   'BI6500 - Antelope Island Bison'],
#  ['RANDY S JULIAN',
#   '5 - Unsuccessful',
#   'PO Box 273',
#   'Stockton UT \n84071-0273',
#   'BI6500 - Antelope Island Bison'],
#  ['MICHAEL R KASSAHN',
#   '5 - Unsuccessful',
#   '9 Park Place Ln',
#   'Centerville UT \n84014-1834',
#   'BI6500 - Antelope Island Bison'],
#  ['ZACHARY K KEARL',
#   '5 - Unsuccessful',
#   '51 S Mustang Ridge Rd',
#   'Grantsville UT \n84029-5030',
#   'BI6500 - Antelope Island Bison'],
#  ['COLE C KELLEY',
#   '5 - Unsuccessful',
#   '1841 S Cameron Dr',
#   'West Haven UT \n84401-8463',
#   'BI6500 - Antelope Island Bison'],
#  ['KAYLA B KELLEY',
#   '5 - Unsuccessful',
#   '1841 S Cameron Dr',
#   'West Haven UT \n84401-8463',
#   'BI6500 - Antelope Island Bison'],
#  ['LUISE KELSON',
#   '5 - Unsuccessful',
#   '2998 S Perennial Ct',
#   'Magna UT \n84044-3216',
#   'BI6500 - Antelope Island Bison'],
#  ['COLEMAN A KENDRICK',
#   '5 - Unsuccessful',
#   '5954 W Birch Water Ln',
#   'West Jordan UT \n84081-5739',
#   'BI6500 - Antelope Island Bison'],
#  ['Robert C Kendrick',
#   '5 - Unsuccessful',
#   '825 S 225 E',
#   'Providence UT \n84332-9864',
#   'BI6500 - Antelope Island Bison'],
#  ['COLTON D KERSHAW',
#   '5 - Unsuccessful',
#   '871 S West Hoytsville Rd',
#   'Coalville UT \n84017-9762',
#   'BI6500 - Antelope Island Bison'],
#  ['Larry D Kesler',
#   '5 - Unsuccessful',
#   '2485 W 7625 S',
#   'West Jordan UT \n84084-3867',
#   'BI6500 - Antelope Island Bison'],
#  ['TOM S KING',
#   '5 - Unsuccessful',
#   '826 S Black Canyon Rd',
#   'Antimony UT \n84712-7730',
#   'BI6500 - Antelope Island Bison'],
#  ['Daymond R Kofford',
#   '5 - Unsuccessful',
#   '2069 E Susan Way',
#   'Cottonwood UT \n84121-3737',
#   'BI6500 - Antelope Island Bison'],
#  ['NICHOLAS J KONCAR',
#   '5 - Unsuccessful',
#   '3478 E Bougival Ln',
#   'Cottonwood Heights \nUT 84093-1208',
#   'BI6500 - Antelope Island Bison'],
#  ['ADAM KROGH',
#   '5 - Unsuccessful',
#   '242 N 1400 W',
#   'Clearfield UT \n84015-8646',
#   'BI6500 - Antelope Island Bison'],
#  ['MICHAEL O LALLAS',
#   '5 - Unsuccessful',
#   '284 E 400 S',
#   'Orem UT 84058-6312',
#   'BI6500 - Antelope Island Bison'],
#  ['MICHAEL E LAMB',
#   '5 - Unsuccessful',
#   '944 E Murdock Dr',
#   'Pleasant Grove UT \n84062-4564',
#   'BI6500 - Antelope Island Bison'],
#  ['STEWART R LAY',
#   '5 - Unsuccessful',
#   '5994 S Susquehanna',
#   'Murray UT \n84123-5527',
#   'BI6500 - Antelope Island Bison'],
#  ['DILLON M LEE',
#   '5 - Unsuccessful',
#   '1464 W 1920 N',
#   'Layton UT 84041-1104',
#   'BI6500 - Antelope Island Bison'],
#  ['MICHAEL E LEWIS',
#   '5 - Unsuccessful',
#   '44 E Magellan Ln',
#   'Elk Ridge UT \n84651-5672',
#   'BI6500 - Antelope Island Bison'],
#  ['MADISON R LINDSEY',
#   '5 - Unsuccessful',
#   '1046 S 900 E Apt B',
#   'Slc UT 84105-1340',
#   'BI6500 - Antelope Island Bison'],
#  ['ASPEN M LOZANO',
#   '5 - Unsuccessful',
#   '39 S 200 W',
#   'Minersville UT \n84752-7764',
#   'BI6500 - Antelope Island Bison'],
#  ['Brian D Lund',
#   '5 - Unsuccessful',
#   '510 E Canyon Rim Rd',
#   'Smithfield UT \n84335-3106',
#   'BI6500 - Antelope Island Bison'],
#  ['Cole Manning',
#   '5 - Unsuccessful',
#   '4783 W 700 S',
#   'West Point UT \n84015-6819',
#   'BI6500 - Antelope Island Bison'],
#  ['ALEXANDER R MARSHALL',
#   '5 - Unsuccessful',
#   '12125 N 9200 W',
#   'Tremonton UT \n84337-9512',
#   'BI6500 - Antelope Island Bison'],
#  ['BURTON W MAY',
#   '5 - Unsuccessful',
#   '2360 S 900 W',
#   'Syracuse UT \n84075-9172',
#   'BI6500 - Antelope Island Bison'],
#  ['JASON D MCCOLLIN',
#   '5 - Unsuccessful',
#   '290 S Main St',
#   'Glenwood UT \n84730-7771',
#   'BI6500 - Antelope Island Bison'],
#  ['CHASE J MCDERMOTT',
# ...
#   ''],
#  ['CRAIG R SAUNDERS',
#   '5 - Unsuccessful',
#   'PO Box 521',
#   'Providence UT \n84332-0521',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Jade J Schell',
#   '5 - Unsuccessful',
#   '73 N 300 W',
#   'Brigham City UT \n84302-2029',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['CAROL L SCHILLING',
#   '5 - Unsuccessful',
#   '889 R Rd',
#   'Mack CO 81525-9758',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['SCOTT W SCHILLING',
#   '5 - Unsuccessful',
#   '889 R Rd',
#   'Mack CO 81525-9758',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Brian D Seals',
#   '5 - Unsuccessful',
#   '1124 Thomas Knapp Pkwy',
#   'Fort Mill SC \n29715-5584',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['David L Severe',
#   '5 - Unsuccessful',
#   '1363 Paxton Dr',
#   'Knoxville TN \n37918-8018',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['BENJAMIN R SHARP',
#   '5 - Unsuccessful',
#   '56 E 100 S',
#   'Tooele UT 84074-2121',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['MEGAN E SHEFFER',
#   '5 - Unsuccessful',
#   '2225 N 3500 W',
#   'Vernal UT 84078-9743',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['TEAGUE SHEFFER',
#   '5 - Unsuccessful',
#   '2225 N 3500 W',
#   'Vernal UT 84078-9743',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['DAKOTA J SHEPHERD',
#   '5 - Unsuccessful',
#   '270 N 100 E',
#   'Salina UT 84654-1204',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Steve D Sidwell',
#   '5 - Unsuccessful',
#   '4033 N Spring Glen Rd',
#   'Helper UT 84526-2010',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Darcy D Simmons',
#   '5 - Unsuccessful',
#   '1177 N 730 E',
#   'Pleasant Grove UT \n84062-1990',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['DEVIN N SKINNER',
#   '5 - Unsuccessful',
#   '1045 W Rooftop Dr',
#   'Midvale UT \n84047-4805',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['BARRY D SMITH',
#   '5 - Unsuccessful',
#   'PO Box 243',
#   'Redmond UT \n84652-0243',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['David G Smith',
#   '5 - Unsuccessful',
#   '7881 N Windhover Rd',
#   'Eagle Mountain UT \n84005-4346',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['MICHELE SMITH',
#   '5 - Unsuccessful',
#   '626 W 1100 S',
#   'Lehi UT 84043-4049',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['SIDNEY M SMITH',
#   '5 - Unsuccessful',
#   '2733 E Gentile St',
#   'Layton UT \n84040-7550',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Hunter J Snelling',
#   '5 - Unsuccessful',
#   '1121 Nursery St',
#   'Fogelsville PA \n18051-1639',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Nathan K Somero',
#   '5 - Unsuccessful',
#   '146 Davis Village Rd',
#   'New Ipswich NH \n03071-3808',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['BRIAN J SORENSEN',
#   '5 - Unsuccessful',
#   '5708 S 4800 W',
#   'Spanish Fork UT \n84660-4200',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['ANNA E SOUTHAM',
#   '5 - Unsuccessful',
#   '571 E 780 N',
#   'Pleasant Grove UT \n84062-1835',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['DANIEL J SOUTHAM',
#   '5 - Unsuccessful',
#   '571 E 780 N',
#   'Pleasant Grove UT \n84062-1835',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['SHAYNA SOUTHAM',
#   '5 - Unsuccessful',
#   '571 E 780 N',
#   'Pleasant Grove UT \n84062-1835',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Dakotah Spencer',
#   '5 - Unsuccessful',
#   '3155 S Hidden Valley Dr \nUnit 315',
#   'Saint George UT \n84790-6981',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['SHYANNE SPENCER',
#   '5 - Unsuccessful',
#   '1057 S 780 W',
#   'Payson UT \n84651-3134',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Jeffrey A Sperry',
#   '5 - Unsuccessful',
#   '299 Green Meadows Ln',
#   'Salem WV \n26426-7614',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['HUNTER M SPURGEON',
#   '5 - Unsuccessful',
#   '941 N Main St',
#   'Mapleton UT \n84664-3470',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['McKell W Squire',
#   '5 - Unsuccessful',
#   '57 W 100 N',
#   'Salem UT 84653-9537',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['ELIZABETH STACEY',
#   '5 - Unsuccessful',
#   '4135 N 2800 W',
#   'Brigham City UT \n84302-3808',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Paul W Stanco',
#   '5 - Unsuccessful',
#   '610 Broken Top Ct',
#   'Folsom CA \n95630-7194',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Eric D Stanosheck',
#   '5 - Unsuccessful',
#   'PO Box 182',
#   'Haslet TX 76052-0182',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Michael C Stebbins',
#   '5 - Unsuccessful',
#   '168 E Helm Ave',
#   'Salt Lake City UT \n84115-4705',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['CHRISTOPHER M \nSTEINWENDER',
#   '5 - Unsuccessful',
#   '2608 Southwestern Dr',
#   'Flower Mound TX \n75028-4562',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Jacob T Stewart',
#   '5 - Unsuccessful',
#   '3040S Limestone Dr',
#   'Saint George UT \n84790-6520',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Timothy A Stewart',
#   '5 - Unsuccessful',
#   '3040 Limestone Dr',
#   'Saint George UT \n84790-6520',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['LAUNA C STUBBLEFIELD',
#   '5 - Unsuccessful',
#   'PO Box 2447',
#   'Beaver UT \n84713-2447',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['TAYLON R SWANGER',
#   '5 - Unsuccessful',
#   '648 E 110 S',
#   'American Fork UT \n84003-2865',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['JON M TANNER',
#   '5 - Unsuccessful',
#   '1937 W Phillips St',
#   'Kaysville UT \n84037-9616',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['CURTIS D TERRY',
#   '5 - Unsuccessful',
#   '1710 N 3250 W',
#   'Cedar City UT \n84721-8100',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Trevor M Terry',
#   '5 - Unsuccessful',
#   '195 N 1240 W',
#   'Saint George UT \n84770-5797',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['TERRENCE G THALMAN',
#   '5 - Unsuccessful',
#   '4609 S PALMER DR',
#   'SALT LAKE CITY UT \n84120',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Trevor V Thalman',
#   '5 - Unsuccessful',
#   '303 E 850 N',
#   'Richfield UT \n84701-1951',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['BRACEN B THEOBALD',
#   '5 - Unsuccessful',
#   '32 W 1320 S',
#   'Payson UT \n84651-3012',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Dustin G Thomas',
#   '5 - Unsuccessful',
#   'PO Box 221',
#   'Milford UT 84751-0221',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Henry Thomas',
#   '5 - Unsuccessful',
#   'PO Box 172',
#   'Stockton UT \n84071-0172',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['JACOB D THOMPSON',
#   '5 - Unsuccessful',
#   '460 E 300 S',
#   'Heber City UT \n84032-2127',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['William R Thompson III',
#   '5 - Unsuccessful',
#   '326 White Post Rd',
#   'White Post VA \n22663-2623',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['ISAAC M TINGEY',
#   '5 - Unsuccessful',
#   '506 Churchill Dr',
#   'Centerville UT \n84014-2614',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['SAMUEL TINGEY',
#   '5 - Unsuccessful',
#   '506 Churchill Dr',
#   'Centerville UT \n84014-2614',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['ALEX TINOCO',
#   '5 - Unsuccessful',
#   '2322 E 1035 S',
#   'Spanish Fork UT \n84660-3505',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Ed Tomsic',
#   '5 - Unsuccessful',
#   '381 Mivida Dr',
#   'Moab UT 84532-2148',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Trevor D Townsend',
#   '5 - Unsuccessful',
#   '11691 SW Houston Lake \nRd',
#   'Powell Butte OR \n97753-1843',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['KYLE Q TURNER',
#   '5 - Unsuccessful',
#   '3515 Doc Raymond',
#   'Flagstaff AZ \n86005-4324',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Marvin R Turner',
#   '5 - Unsuccessful',
#   '1430 N BLACK KNOLL \nRD',
#   'RICHFIELD UT 84701',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['BRIAN L TUTTLE',
#   '5 - Unsuccessful',
#   '6240 Woodmen Park Vw',
#   'Colorado Springs CO \n80923-2616',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['CHRISTOPHER J TYMESON',
#   '5 - Unsuccessful',
#   '3617 W 157th St',
#   'Overland Park KS \n66224-3888',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['ALVARO A UMANA',
#   '5 - Unsuccessful',
#   '918 N 720 W',
#   'Tooele UT 84074-1391',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['COLB T URIE',
#   '5 - Unsuccessful',
#   '1473 E Highland Trails Rd',
#   'Enoch UT 84721-7870',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['JULIAN VEGA',
#   '5 - Unsuccessful',
#   'PO Box 366',
#   'Minersville UT \n84752-0366',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['kevin g vessey',
#   '5 - Unsuccessful',
#   'PO Box 839',
#   'Ennis MT 59729-0839',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['JOHN M VIGRASS',
#   '5 - Unsuccessful',
#   '1275 Nicola Dr',
#   'Riverside CA \n92506-3622',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Paul E VreNon',
#   '5 - Unsuccessful',
#   '8650 Spring Mountain Rd \nSte 101',
#   'Las Vegas NV \n89117-4106',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['TYLER J WADSWORTH',
#   '5 - Unsuccessful',
#   '229 E Cherry St',
#   'Grantsville UT \n84029-9412',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['WILLIAM E WALDEN',
#   '5 - Unsuccessful',
#   'PO Box 340',
#   'Mona UT 84645-0340',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['scott j waletzko',
#   '5 - Unsuccessful',
#   'PO Box 454',
#   'Bonner MT \n59823-0454',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Heath A Walk',
#   '5 - Unsuccessful',
#   '252 mt Charma Rd',
#   'TYRONE PA 16601',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Uriah H Walk',
#   '5 - Unsuccessful',
#   '252 MT Charma Dr',
#   'Altoona PA 16601',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Bryan B Walker',
#   '5 - Unsuccessful',
#   '833 W Faraday Ln',
#   'Pleasant Grove UT \n84062-5544',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['DAKOTA K WALSER',
#   '5 - Unsuccessful',
#   '322 W 100 N',
#   'Monroe UT \n84754-4164',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['MARK L WALTER',
#   '5 - Unsuccessful',
#   '35820 N 17th Ave',
#   'Phoenix AZ \n85086-7250',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Jake L Warren',
#   '5 - Unsuccessful',
#   'PO Box 945',
#   'Parowan UT \n84761-0945',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['SPENCER D WATERS',
#   '5 - Unsuccessful',
#   '26 Smith St',
#   'Warwick RI \n02886-3438',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['RIKER D WEBER',
#   '5 - Unsuccessful',
#   '3640 W 3500 S',
#   'Meadow UT \n84644-7709',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Wendell S WEEKS',
#   '5 - Unsuccessful',
#   'PO Box 25',
#   'Monroe UT \n84754-0025',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Bradley M Weiss',
#   '5 - Unsuccessful',
#   '6322 94th Ct',
#   'Kenosha WI \n53142-8229',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['MARTIN W WELCKER',
#   '5 - Unsuccessful',
#   '906 N 1020 E',
#   'Pleasant Grove UT \n84062-2029',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['TAMMY A WELCKER',
#   '5 - Unsuccessful',
#   '906 N 1020 E',
#   'Pleasant Grove UT \n84062-2029',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['TONY e WENDELL',
#   '5 - Unsuccessful',
#   '998 W 1450 S',
#   'Payson UT \n84651-8624',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['ZACHARIA J WESTERN',
#   '5 - Unsuccessful',
#   '2045 E 3500 S',
#   'Vernal UT 84078-9182',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Gary L Whatcott',
#   '5 - Unsuccessful',
#   '1461 W Balsam Fir Ct',
#   'South Jordan UT \n84095-8366',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Berkley White',
#   '5 - Unsuccessful',
#   '361 W 200 N # 60',
#   'Mount Pleasant UT \n84647-1355',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['TYLER K WHITE',
#   '5 - Unsuccessful',
#   '570 FM 1510',
#   'Scroggins TX 75480',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['THOMAS L WHITING',
#   '5 - Unsuccessful',
#   '8850 W Blazing Oak Dr',
#   'Magna UT \n84044-2861',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Tyler B Whittaker',
#   '5 - Unsuccessful',
#   '1945 W 150 S',
#   'Cedar City UT \n84720-2858',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Paul J Wick',
#   '5 - Unsuccessful',
#   '4204 W Okanogan Ave',
#   'Kennewick WA \n99336-2333',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['KASEY L WILKEY',
#   '5 - Unsuccessful',
#   '6691 S Clernates Dr',
#   'West Jordan UT \n84081-4404',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['MARK E WILKEY',
#   '5 - Unsuccessful',
#   '14646 S. WOODS \nCOURT LANDING',
#   'DRAPER UT 84020',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Russell Willden',
#   '5 - Unsuccessful',
#   '184 S Meadowbrook Dr',
#   'Salina UT 84654-5536',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Mitchell B Willes',
#   '5 - Unsuccessful',
#   '623 S 100 E',
#   'Payson UT \n84651-3301',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Blake l Williams',
#   '5 - Unsuccessful',
#   'PO Box 933',
#   'Milford UT 84751-0933',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Jason B Williams Nixon',
#   '5 - Unsuccessful',
#   '5457 W Shaggy Peak Dr',
#   'Herriman UT \n84096-6655',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['DURVEN WILSON',
#   '5 - Unsuccessful',
#   '9973 EDEN POINT CIR \nEDEN POINT CIR',
#   'SOUTH JORDAN UT \n84095',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['MARCUS E WILSON',
#   '5 - Unsuccessful',
#   'PO Box 42',
#   'Hanksville UT \n84734-0042',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Chelcie A Wimmer',
#   '5 - Unsuccessful',
#   '5479 W 8400 S',
#   'Payson UT \n84651-9735',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['KARLIN S WINTER',
#   '5 - Unsuccessful',
#   '142 W 400 S',
#   'Nephi UT 84648-1752',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['MASON A WISER',
#   '5 - Unsuccessful',
#   '1296 E 150 S',
#   'Spanish Fork UT \n84660-2370',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Daniel S Wood',
#   '5 - Unsuccessful',
#   '968 W 1620 S',
#   'Payson UT \n84651-1864',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['BRYLEE P WORTHEN',
#   '5 - Unsuccessful',
#   'PO Box 418',
#   'Levan UT 84639-0418',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Denton L Worthington',
#   '5 - Unsuccessful',
#   '7155 S 4000 W',
#   'Spanish Fork UT \n84660-4121',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['TYLER M WRIGHT',
#   '5 - Unsuccessful',
#   '5343 S Hew Wood Dr',
#   'Taylorsville UT \n84129-1367',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Bruce J Wyant',
#   '5 - Unsuccessful',
#   '11508 Buffington St',
#   'Bakersfield CA \n93312-4693',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Jeff S Yancy',
#   '5 - Unsuccessful',
#   '22375 Adobe Rd',
#   'Red Bluff CA \n96080-9301',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['KATELYNN E YATES',
#   '5 - Unsuccessful',
#   '598 Lynnbrook Dr',
#   'Spanish Fork UT \n84660-1378',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Ronald C Yocom',
#   '5 - Unsuccessful',
#   '2703 SMR B-102',
#   'FAIRVIEW UT 84629',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['RICHEY L YOUNG',
#   '5 - Unsuccessful',
#   '3763 S Old Silo Way',
#   'West Valley City UT \n84119-4022',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['DARRIN L ZINGLEMAN',
#   '5 - Unsuccessful',
#   '12523 S Jeannette Ln',
#   'Herriman UT \n84096-5137',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['TIMOTHY E ZOLINIAK',
#   '5 - Unsuccessful',
#   '193 Rainbow Ln',
#   'Watsonville CA \n95076-0723',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['DANIEL S ZUBAK',
#   '5 - Unsuccessful',
#   '3845 Goddard Way',
#   'Corona CA \n92882-8328',
#   'BI6503 - Bison (Hunter’s Choice)',
#   ''],
#  ['Barry J Albrecht',
#   '5 - Unsuccessful',
#   'PO Box 556',
#   'Aurora UT 84620-0556',
#   'BI6504 - Bison (Hunter’s Choice)',
#   None],
#  ['STANLEY K ALLAN',
#   '5 - Unsuccessful',
#   '130 E 1050 N',
#   'Hurricane UT \n84737-1754',
#   'BI6504 - Bison (Hunter’s Choice)',
#   None],
#  ['MCQUAE J ANDERSON',
#   '5 - Unsuccessful',
#   '111 S Main St',
#   'Holden UT \n84636-7721',
#   'BI6504 - Bison (Hunter’s Choice)',
#   None],
#  ['Tracy L Anderson',
#   '5 - Unsuccessful',
#   '4148 W 4250 S',
#   'Delta UT 84624-7955',
#   'BI6504 - Bison (Hunter’s Choice)',
#   None],
#  ['Amos A Auberry',
#   '5 - Unsuccessful',
#   '11575 E 27th Pl',
#   'Yuma AZ 85367-4933',
#   'BI6504 - Bison (Hunter’s Choice)',
#   None],
#  ['daniel l bach',
#   '5 - Unsuccessful',
#   '4533 SW Umatilla Ave',
#   'Redmond OR \n97756-7573',
#   'BI6504 - Bison (Hunter’s Choice)',
#   None],
#  ['TAYLEE R BAGLEY',
#   '5 - Unsuccessful',
#   '151 E 300 N',
#   'Lehi UT 84043-1817',
#   'BI6504 - Bison (Hunter’s Choice)',
#   None],
#  ...]

# %% [markdown]
# ### Regex is weird, do a little test

# %%
# regex debugging
import re

re.split(r"(UT)", "Salt Lake City UT 84103-1234")
# Out:
# ['Salt Lake City ', 'UT', ' 84103-1234']

# %%
import re

# function to parse City, State, Zip -> returns tuple

pattern = r'(A[LKSZRAEP]|C[AOT]|D[EC]|F[LM]|G[AU]|HI|I[ADLN]|K[SY]|LA|M[ADEHINOPST]|N[CDEHJMVY]|O[HKR]|P[ARW]|RI|S[CD]|T[NX]|UT|V[AIT]|W[AIVY])'

def parseCityState(full_address):
    return re.split(pattern, full_address)

# %%
# Name, Status, Address, City/State/Zip, Hunt Info

f = open('results.csv', 'w')

# write headers
f.write('name, status, address, city, state, zip, hunt\n')

for row in table:
    row[2] = row[2].replace('\n', '')
    row[3] = row[3].replace('\n', '')
    temp_row_3 = parseCityState(row[3])
    real_row_3 = ', '.join(temp_row_3)
    f.write(f'{row[0]}, {row[1]}, {row[2]}, {real_row_3}, {row[4]}\n')
f.close()
f
# Out:
# <_io.TextIOWrapper name='results.csv' mode='w' encoding='cp1252'>
